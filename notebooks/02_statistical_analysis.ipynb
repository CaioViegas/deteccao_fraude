# %% [markdown]
# ##### Importações

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
df = pd.read_csv("../data/transformed/transformed_cybersecurity_intrusion_data.csv")

# %%
df.head()
# Out:
#   session_id  network_packet_size protocol_type  login_attempts  \
# 0  SID_00001                599.0           TCP             4.0
# 1  SID_00002                472.0           TCP             3.0
# 2  SID_00003                629.0           TCP             3.0
# 3  SID_00005                453.0           TCP             5.0
# 4  SID_00006                453.0           UDP             5.0
#
#    session_duration encryption_used  ip_reputation_score  failed_logins  \
# 0        492.983263             DES             0.606818            1.0
# 1       1557.996461             DES             0.301569            0.0
# 2         75.044262             DES             0.739164            2.0
# 3        532.540888             AES             0.054874            1.0
# 4        380.471550             AES             0.422486            2.0
#
#   browser_type  unusual_time_access  attack_detected  long_session  \
# 0         Edge                  0.0              1.0             0
# 1      Firefox                  0.0              0.0             1
# 2       Chrome                  0.0              1.0             0
# 3      Firefox                  0.0              0.0             0
# 4       Chrome                  1.0              0.0             0
#
#   protocol_encrypt  large_packet  risk_score
# 0          TCP_DES             1    0.724773
# 1          TCP_DES             0    0.211098
# 2          TCP_DES             1    1.117415
# 3          TCP_AES             0    0.338412
# 4          UDP_AES             0    0.895740

# %% [markdown]
# ##### Análise Estatística

# %%
df_numeric = df.select_dtypes(include=[np.number])

# %%
print(f"Number of rows: {df.shape[0]}, Number of columns: {df.shape[1]}")
# Out:
# Number of rows: 7174, Number of columns: 15

# %%
def describe_plus(df, cmap="Blues", decimals=2):
    df_num = df.select_dtypes(include=[np.number])
    
    extra = pd.DataFrame({
        "median": df_num.median(),
        "iqr": df_num.quantile(0.75) - df_num.quantile(0.25),
        "cv": df_num.std() / df_num.mean(),
        "skew": df_num.skew(),
        "kurtosis": df_num.kurtosis(),
        "amplitude": df_num.max() - df_num.min(),
        "coef_var": df_num.apply(lambda x: stats.variation(x.dropna()))
    })
    summary = pd.concat([df_num.describe().T, extra], axis=1)
    
    return summary.style.background_gradient(cmap=cmap).format(f"{{:.{decimals}f}}")

# %%
describe_plus(df, cmap="plasma")
# Out:
# <style type="text/css">
# #T_d1231_row0_col0, #T_d1231_row0_col10, #T_d1231_row0_col14, #T_d1231_row1_col0, #T_d1231_row1_col2, #T_d1231_row1_col7, #T_d1231_row1_col9, #T_d1231_row1_col13, #T_d1231_row2_col0, #T_d1231_row3_col0, #T_d1231_row3_col1, #T_d1231_row3_col2, #T_d1231_row3_col3, #T_d1231_row3_col4, #T_d1231_row3_col5, #T_d1231_row3_col6, #T_d1231_row3_col7, #T_d1231_row3_col8, #T_d1231_row3_col9, #T_d1231_row3_col13, #T_d1231_row4_col0, #T_d1231_row4_col1, #T_d1231_row4_col2, #T_d1231_row4_col3, #T_d1231_row4_col4, #T_d1231_row4_col5, #T_d1231_row4_col6, #T_d1231_row4_col7, #T_d1231_row4_col8, #T_d1231_row4_col9, #T_d1231_row4_col13, #T_d1231_row5_col0, #T_d1231_row5_col1, #T_d1231_row5_col2, #T_d1231_row5_col3, #T_d1231_row5_col4, #T_d1231_row5_col5, #T_d1231_row5_col6, #T_d1231_row5_col7, #T_d1231_row5_col8, #T_d1231_row5_col9, #T_d1231_row5_col13, #T_d1231_row6_col0, #T_d1231_row6_col1, #T_d1231_row6_col2, #T_d1231_row6_col3, #T_d1231_row6_col4, #T_d1231_row6_col5, #T_d1231_row6_col6, #T_d1231_row6_col7, #T_d1231_row6_col8, #T_d1231_row6_col9, #T_d1231_row6_col13, #T_d1231_row7_col0, #T_d1231_row7_col1, #T_d1231_row7_col2, #T_d1231_row7_col3, #T_d1231_row7_col4, #T_d1231_row7_col5, #T_d1231_row7_col6, #T_d1231_row7_col7, #T_d1231_row7_col8, #T_d1231_row7_col9, #T_d1231_row7_col11, #T_d1231_row7_col12, #T_d1231_row7_col13, #T_d1231_row8_col0, #T_d1231_row8_col1, #T_d1231_row8_col2, #T_d1231_row8_col3, #T_d1231_row8_col4, #T_d1231_row8_col5, #T_d1231_row8_col6, #T_d1231_row8_col7, #T_d1231_row8_col8, #T_d1231_row8_col9, #T_d1231_row8_col11, #T_d1231_row8_col12, #T_d1231_row8_col13, #T_d1231_row9_col0, #T_d1231_row9_col1, #T_d1231_row9_col2, #T_d1231_row9_col3, #T_d1231_row9_col4, #T_d1231_row9_col5, #T_d1231_row9_col6, #T_d1231_row9_col7, #T_d1231_row9_col8, #T_d1231_row9_col9, #T_d1231_row9_col13 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_d1231_row0_col1, #T_d1231_row2_col4 {
#   background-color: #e76f5a;
#   color: #f1f1f1;
# }
# #T_d1231_row0_col2 {
#   background-color: #7e03a8;
#   color: #f1f1f1;
# }
# #T_d1231_row0_col3, #T_d1231_row0_col4, #T_d1231_row2_col1, #T_d1231_row2_col2, #T_d1231_row2_col5, #T_d1231_row2_col6, #T_d1231_row2_col7, #T_d1231_row2_col8, #T_d1231_row2_col9, #T_d1231_row2_col11, #T_d1231_row2_col12, #T_d1231_row2_col13, #T_d1231_row5_col10, #T_d1231_row5_col14 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_d1231_row0_col5, #T_d1231_row0_col8 {
#   background-color: #fbd524;
#   color: #000000;
# }
# #T_d1231_row0_col6 {
#   background-color: #dc5d67;
#   color: #f1f1f1;
# }
# #T_d1231_row0_col7, #T_d1231_row3_col12 {
#   background-color: #6100a7;
#   color: #f1f1f1;
# }
# #T_d1231_row0_col9 {
#   background-color: #9410a2;
#   color: #f1f1f1;
# }
# #T_d1231_row0_col11 {
#   background-color: #260591;
#   color: #f1f1f1;
# }
# #T_d1231_row0_col12, #T_d1231_row4_col12 {
#   background-color: #6c00a8;
#   color: #f1f1f1;
# }
# #T_d1231_row0_col13 {
#   background-color: #5c01a6;
#   color: #f1f1f1;
# }
# #T_d1231_row1_col1, #T_d1231_row1_col5, #T_d1231_row1_col6, #T_d1231_row1_col8 {
#   background-color: #100788;
#   color: #f1f1f1;
# }
# #T_d1231_row1_col3 {
#   background-color: #19068c;
#   color: #f1f1f1;
# }
# #T_d1231_row1_col4, #T_d1231_row2_col3, #T_d1231_row6_col12 {
#   background-color: #130789;
#   color: #f1f1f1;
# }
# #T_d1231_row1_col10, #T_d1231_row1_col14, #T_d1231_row9_col10, #T_d1231_row9_col14 {
#   background-color: #280592;
#   color: #f1f1f1;
# }
# #T_d1231_row1_col11 {
#   background-color: #8a09a5;
#   color: #f1f1f1;
# }
# #T_d1231_row1_col12 {
#   background-color: #8305a7;
#   color: #f1f1f1;
# }
# #T_d1231_row2_col10, #T_d1231_row2_col14, #T_d1231_row7_col10, #T_d1231_row7_col14, #T_d1231_row8_col10, #T_d1231_row8_col14 {
#   background-color: #920fa3;
#   color: #f1f1f1;
# }
# #T_d1231_row3_col10, #T_d1231_row3_col14 {
#   background-color: #350498;
#   color: #f1f1f1;
# }
# #T_d1231_row3_col11 {
#   background-color: #7201a8;
#   color: #f1f1f1;
# }
# #T_d1231_row4_col10, #T_d1231_row4_col14, #T_d1231_row6_col11 {
#   background-color: #5302a3;
#   color: #f1f1f1;
# }
# #T_d1231_row4_col11 {
#   background-color: #6700a8;
#   color: #f1f1f1;
# }
# #T_d1231_row5_col11 {
#   background-color: #fbd724;
#   color: #000000;
# }
# #T_d1231_row5_col12 {
#   background-color: #b6308b;
#   color: #f1f1f1;
# }
# #T_d1231_row6_col10, #T_d1231_row6_col14 {
#   background-color: #ad2793;
#   color: #f1f1f1;
# }
# #T_d1231_row9_col11 {
#   background-color: #5e01a6;
#   color: #f1f1f1;
# }
# #T_d1231_row9_col12 {
#   background-color: #6f00a8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d1231">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1231_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_d1231_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_d1231_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_d1231_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_d1231_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_d1231_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_d1231_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_d1231_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_d1231_level0_col8" class="col_heading level0 col8" >median</th>
#       <th id="T_d1231_level0_col9" class="col_heading level0 col9" >iqr</th>
#       <th id="T_d1231_level0_col10" class="col_heading level0 col10" >cv</th>
#       <th id="T_d1231_level0_col11" class="col_heading level0 col11" >skew</th>
#       <th id="T_d1231_level0_col12" class="col_heading level0 col12" >kurtosis</th>
#       <th id="T_d1231_level0_col13" class="col_heading level0 col13" >amplitude</th>
#       <th id="T_d1231_level0_col14" class="col_heading level0 col14" >coef_var</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1231_level0_row0" class="row_heading level0 row0" >network_packet_size</th>
#       <td id="T_d1231_row0_col0" class="data row0 col0" >7174.00</td>
#       <td id="T_d1231_row0_col1" class="data row0 col1" >499.98</td>
#       <td id="T_d1231_row0_col2" class="data row0 col2" >198.35</td>
#       <td id="T_d1231_row0_col3" class="data row0 col3" >64.00</td>
#       <td id="T_d1231_row0_col4" class="data row0 col4" >364.00</td>
#       <td id="T_d1231_row0_col5" class="data row0 col5" >500.00</td>
#       <td id="T_d1231_row0_col6" class="data row0 col6" >633.00</td>
#       <td id="T_d1231_row0_col7" class="data row0 col7" >1270.00</td>
#       <td id="T_d1231_row0_col8" class="data row0 col8" >500.00</td>
#       <td id="T_d1231_row0_col9" class="data row0 col9" >269.00</td>
#       <td id="T_d1231_row0_col10" class="data row0 col10" >0.40</td>
#       <td id="T_d1231_row0_col11" class="data row0 col11" >0.09</td>
#       <td id="T_d1231_row0_col12" class="data row0 col12" >-0.18</td>
#       <td id="T_d1231_row0_col13" class="data row0 col13" >1206.00</td>
#       <td id="T_d1231_row0_col14" class="data row0 col14" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_d1231_level0_row1" class="row_heading level0 row1" >login_attempts</th>
#       <td id="T_d1231_row1_col0" class="data row1 col0" >7174.00</td>
#       <td id="T_d1231_row1_col1" class="data row1 col1" >4.03</td>
#       <td id="T_d1231_row1_col2" class="data row1 col2" >1.97</td>
#       <td id="T_d1231_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_d1231_row1_col4" class="data row1 col4" >3.00</td>
#       <td id="T_d1231_row1_col5" class="data row1 col5" >4.00</td>
#       <td id="T_d1231_row1_col6" class="data row1 col6" >5.00</td>
#       <td id="T_d1231_row1_col7" class="data row1 col7" >13.00</td>
#       <td id="T_d1231_row1_col8" class="data row1 col8" >4.00</td>
#       <td id="T_d1231_row1_col9" class="data row1 col9" >2.00</td>
#       <td id="T_d1231_row1_col10" class="data row1 col10" >0.49</td>
#       <td id="T_d1231_row1_col11" class="data row1 col11" >0.59</td>
#       <td id="T_d1231_row1_col12" class="data row1 col12" >0.35</td>
#       <td id="T_d1231_row1_col13" class="data row1 col13" >12.00</td>
#       <td id="T_d1231_row1_col14" class="data row1 col14" >0.49</

# %%
corr_matrix = df_numeric.corr(method='pearson')
corr_matrix.style.background_gradient(cmap="coolwarm").format("{:.3f}")
# Out:
# <style type="text/css">
# #T_d4122_row0_col0, #T_d4122_row1_col1, #T_d4122_row2_col2, #T_d4122_row3_col3, #T_d4122_row4_col4, #T_d4122_row5_col5, #T_d4122_row6_col6, #T_d4122_row7_col7, #T_d4122_row8_col8, #T_d4122_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d4122_row0_col1, #T_d4122_row0_col2, #T_d4122_row0_col4, #T_d4122_row0_col7, #T_d4122_row1_col2, #T_d4122_row2_col3, #T_d4122_row3_col0, #T_d4122_row4_col7, #T_d4122_row5_col8, #T_d4122_row7_col6, #T_d4122_row8_col2, #T_d4122_row9_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d4122_row0_col3, #T_d4122_row1_col5, #T_d4122_row2_col0, #T_d4122_row4_col3, #T_d4122_row8_col3, #T_d4122_row8_col9 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_d4122_row0_col5, #T_d4122_row1_col3, #T_d4122_row3_col8, #T_d4122_row5_col6, #T_d4122_row5_col7, #T_d4122_row7_col0, #T_d4122_row8_col7, #T_d4122_row9_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_d4122_row0_col6, #T_d4122_row1_col0, #T_d4122_row1_col4, #T_d4122_row1_col8, #T_d4122_row1_col9, #T_d4122_row3_col2, #T_d4122_row3_col5, #T_d4122_row3_col7, #T_d4122_row4_col0, #T_d4122_row4_col1, #T_d4122_row4_col8, #T_d4122_row5_col3, #T_d4122_row6_col0, #T_d4122_row6_col8, #T_d4122_row9_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d4122_row0_col8, #T_d4122_row8_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_d4122_row0_col9, #T_d4122_row2_col5, #T_d4122_row2_col8, #T_d4122_row3_col1, #T_d4122_row4_col5, #T_d4122_row5_col9, #T_d4122_row6_col5, #T_d4122_row6_col7, #T_d4122_row7_col5, #T_d4122_row7_col9, #T_d4122_row8_col1, #T_d4122_row8_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_d4122_row1_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_d4122_row1_col7, #T_d4122_row4_col2, #T_d4122_row5_col4, #T_d4122_row7_col4, #T_d4122_row8_col5, #T_d4122_row9_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_d4122_row2_col1, #T_d4122_row7_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d4122_row2_col4, #T_d4122_row6_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_d4122_row2_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_d4122_row2_col7 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_d4122_row2_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_d4122_row3_col4, #T_d4122_row5_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_d4122_row3_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_d4122_row3_col9 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_d4122_row4_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_d4122_row4_col9, #T_d4122_row9_col4 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_d4122_row5_col0, #T_d4122_row5_col2, #T_d4122_row7_col3, #T_d4122_row7_col8, #T_d4122_row8_col6, #T_d4122_row9_col0, #T_d4122_row9_col8 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d4122_row6_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_d4122_row6_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_d4122_row6_col4, #T_d4122_row9_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_d4122_row6_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_d4122_row7_col2 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_d4122_row9_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# </style>
# <table id="T_d4122">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4122_level0_col0" class="col_heading level0 col0" >network_packet_size</th>
#       <th id="T_d4122_level0_col1" class="col_heading level0 col1" >login_attempts</th>
#       <th id="T_d4122_level0_col2" class="col_heading level0 col2" >session_duration</th>
#       <th id="T_d4122_level0_col3" class="col_heading level0 col3" >ip_reputation_score</th>
#       <th id="T_d4122_level0_col4" class="col_heading level0 col4" >failed_logins</th>
#       <th id="T_d4122_level0_col5" class="col_heading level0 col5" >unusual_time_access</th>
#       <th id="T_d4122_level0_col6" class="col_heading level0 col6" >attack_detected</th>
#       <th id="T_d4122_level0_col7" class="col_heading level0 col7" >long_session</th>
#       <th id="T_d4122_level0_col8" class="col_heading level0 col8" >large_packet</th>
#       <th id="T_d4122_level0_col9" class="col_heading level0 col9" >risk_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4122_level0_row0" class="row_heading level0 row0" >network_packet_size</th>
#       <td id="T_d4122_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_d4122_row0_col1" class="data row0 col1" >-0.004</td>
#       <td id="T_d4122_row0_col2" class="data row0 col2" >0.022</td>
#       <td id="T_d4122_row0_col3" class="data row0 col3" >0.013</td>
#       <td id="T_d4122_row0_col4" class="data row0 col4" >-0.002</td>
#       <td id="T_d4122_row0_col5" class="data row0 col5" >-0.000</td>
#       <td id="T_d4122_row0_col6" class="data row0 col6" >-0.005</td>
#       <td id="T_d4122_row0_col7" class="data row0 col7" >0.008</td>
#       <td id="T_d4122_row0_col8" class="data row0 col8" >0.801</td>
#       <td id="T_d4122_row0_col9" class="data row0 col9" >0.003</td>
#     </tr>
#     <tr>
#       <th id="T_d4122_level0_row1" class="row_heading level0 row1" >login_attempts</th>
#       <td id="T_d4122_row1_col0" class="data row1 col0" >-0.004</td>
#       <td id="T_d4122_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_d4122_row1_col2" class="data row1 col2" >0.020</td>
#       <td id="T_d4122_row1_col3" class="data row1 col3" >0.001</td>
#       <td id="T_d4122_row1_col4" class="data row1 col4" >-0.021</td>
#       <td id="T_d4122_row1_col5" class="data row1 col5" >0.013</td>
#       <td id="T_d4122_row1_col6" class="data row1 col6" >0.264</td>
#       <td id="T_d4122_row1_col7" class="data row1 col7" >0.021</td>
#       <td id="T_d4122_row1_col8" class="data row1 col8" >0.002</td>
#       <td id="T_d4122_row1_col9" class="data row1 col9" >-0.019</td>
#     </tr>
#     <tr>
#       <th id="T_d4122_level0_row2" class="row_heading level0 row2" >session_duration</th>
#       <td id="T_d4122_row2_col0" class="data row2 col0" >0.022</td>
#       <td id="T_d4122_row2_col1" class="data row2 col1" >0.020</td>
#       <td id="T_d4122_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_d4122_row2_col3" class="data row2 col3" >0.003</td>
#       <td id="T_d4122_row2_col4" class="data row2 col4" >0.033</td>
#       <td id="T_d4122_row2_col5" class="data row2 col5" >0.009</td>
#       <td id="T_d4122_row2_col6" class="data row2 col6" >0.055</td>
#       <td id="T_d4122_row2_col7" class="data row2 col7" >0.689</td>
#       <td id="T_d4122_row2_col8" class="data row2 col8" >0.021</td>
#       <td id="T_d4122_row2_col9" class="data row2 col9" >0.031</td>
#     </tr>
#     <tr>
#       <th id="T_d4122_level0_row3" class="row_heading level0 row3" >ip_reputation_score</th>
#       <td id="T_d4122_row3_col0" class="data row3 col0" >0.013</td>
#       <td id="T_d4122_row3_col1" class="data row3 col1" >0.001</td>
#       <td id="T_d4122_row3_col2" class="data row3 col2" >0.003</td>
#       <td id="T_d4122_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_d4122_row3_col4" class="data row3 col4" >0.013</td>
#       <td id="T_d4122_row3_col5" class="data row3 col5" >-0.013</td>
#       <td id="T_d4122_row3_col6" class="data row3 col6" >0.225</td>
#       <td id="T_d4122_row3_col7" class="data row3 col7" >-0.008</td>
#       <td id="T_d4122_row3_col8" class="data row3 col8" >0.013</td>
#       <td id="T_d4122_row3_col9" class="data row3 col9" >0.384</td>
#     </tr>
#     <tr>
#       <th id="T_d4122_level0_row4" class="row_heading level0 row4" >failed_logins</th>
#       <td id="T_d4122_row4_col0" class="data row4 col0" >-0.002</td>
#       <td id="T_d4122_row4_col1" class="data row4 col1" >-0.021</td>
#       <td id="T_d4122_row4_col2" class="data row4 col2" >0.033</td>
#       <td id="T_d4122_row4_col3" class="data row4 col3" >0.013</td>
#       <td id="T_d4122_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_d4122_row4_col5" class="data row4 col5"

# %%
df_correlation = pd.read_csv("../data/processed/processed_cybersecurity_intrusion_data.csv")

# %%
def normality_test_fluxogram(series, alpha=0.05):
    x = series.dropna()
    n = len(x)
    if n < 3:
        return {'teste': None, 'estatistica': None, 'p_valor': None,
                'interpretacao': 'Amostra muito pequena para testes de normalidade.'}
    
    q1 = np.percentile(x, 25)
    q3 = np.percentile(x, 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5*iqr
    upper_bound = q3 + 1.5*iqr
    n_outliers = ((x < lower_bound) | (x > upper_bound)).sum()
    prop_outliers = n_outliers / n
    
    muitos_outliers = prop_outliers > 0.01

    if muitos_outliers:
        try:
            stat, pval = stats.lilliefors(x, dist='norm')
            teste = 'Lilliefors (KS ajustado)'
            result = None
        except:
            result = stats.anderson(x, dist='norm')
            stat = result.statistic
            pval = None
            teste = 'Anderson-Darling'
    else:
        if n < 50:
            stat, pval = stats.shapiro(x)
            teste = 'Shapiro-Wilk'
            result = None
        elif 50 <= n <= 5000:
            stat, pval = stats.shapiro(x)
            teste = 'Shapiro-Wilk'
            result = None
        else:
            stat, pval = stats.normaltest(x)
            teste = 'DAgostino-Pearson'
            result = None

    if pval is None:
        crit_5pct = None
        if result is not None:
            for cv, sl in zip(result.critical_values, result.significance_level):
                if sl == 5:
                    crit_5pct = cv
                    break
        if crit_5pct is not None and stat < crit_5pct:
            interpret = 'Provavelmente normal (não rejeita H0 no nível 5%)'
        else:
            interpret = 'Provavelmente não normal (rejeita H0 no nível 5%)'
        pval_str = 'N/A'

    else:
        pval_str = f'{pval:.4f}'
        if pval > alpha:
            interpret = 'Provavelmente normal (não rejeita H0)'
        else:
            interpret = 'Provavelmente não normal (rejeita H0)'

    return {'teste': teste,
            'estatistica': stat,
            'p_valor': pval_str,
            'interpretacao': interpret}

# %%
for col in df.select_dtypes(include=[np.number]).columns:
    print(f'--- Coluna: {col} ---')
    resultado = normality_test_fluxogram(df[col], alpha=0.05)
    for k,v in resultado.items():
        print(f'{k}: {v}')
    print('\n')
# Out:
# --- Coluna: network_packet_size ---
# teste: DAgostino-Pearson
# estatistica: 21.51383340771568
# p_valor: 0.0000
# interpretacao: Provavelmente não normal (rejeita H0)
#
#
# --- Coluna: login_attempts ---
# teste: Anderson-Darling
# estatistica: 104.03917350582924
# p_valor: N/A
# interpretacao: Provavelmente não normal (rejeita H0 no nível 5%)
#
#
# --- Coluna: session_duration ---
# teste: Anderson-Darling
# estatistica: 331.29627471515414
# p_valor: N/A
# interpretacao: Provavelmente não normal (rejeita H0 no nível 5%)
#
#
# --- Coluna: ip_reputation_score ---
# teste: DAgostino-Pearson
# estatistica: 311.7387739840571
# p_valor: 0.0000
# interpretacao: Provavelmente não normal (rejeita H0)
#
#
# --- Coluna: failed_logins ---
# teste: Anderson-Darling
# estatistica: 289.68962874121644
# p_valor: N/A
# interpretacao: Provavelmente não normal (rejeita H0 no nível 5%)
#
#
# --- Coluna: unusual_time_access ---
# teste: Anderson-Darling
# estatistica: 2116.62860675278
# p_valor: N/A
# interpretacao: Provavelmente não normal (rejeita H0 no nível 5%)
#
#
# --- Coluna: attack_detected ---
# teste: DAgostino-Pearson
# estatistica: 26235.886637323434
# p_valor: 0.0000
# interpretacao: Provavelmente não normal (rejeita H0)
#
#
# --- Coluna: long_session ---
# teste: DAgostino-Pearson
# estatistica: 24778.60251769478
# p_valor: 0.0000
# interpretacao: Provavelmente não normal (rejeita H0)
#
#
# --- Coluna: large_packet ---
# teste: DAgostino-Pearson
# estatistica: 24777.64400765489
# p_valor: 0.0000
# interpretacao: Provavelmente não normal (rejeita H0)
#
#
# --- Coluna: risk_score ---
# teste: DAgostino-Pearson
# estatistica: 144.2892791841153
# p_valor: 0.0000
# interpretacao: Provavelmente não normal (rejeita H0)
